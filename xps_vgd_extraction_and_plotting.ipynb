# %% [markdown]
# # Start-to-end .VGD extraction workflow:
# 1. import packages
# 2. read .VGD file
# 3. convert spectra to pandas DataFrame
# 4. export to CSV
# 5. plot normalised intensity

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
import os
import sys

XPS_DIR = Path(
    "data/raw"
)

os.chdir(XPS_DIR)

if str(XPS_DIR) not in sys.path:
    sys.path.insert(0, str(XPS_DIR))

print("Working directory:", Path.cwd())
print("Python:", sys.executable)

# %%
from xps_vgd_utils import (
    read_vgd_to_dataframe,
    add_normalised_intensity,
    save_xps_outputs,
    save_khervefitting_xlsx,
    extract_peak_maximum,
    plot_normalised_xps,
)

PEAK_WINDOWS = {
    "C 1s": (280, 292),
    "N 1s": (395, 402),
    "O 1s": (526, 536),
    "S 2p": (158, 170),
    "Cl 2p": (195, 205),
    "Zn 2p3/2": (1018, 1026),
    "In 3d5/2": (441, 448),
}

CORE_LEVEL_COLOURS = {
    # Canonical labels used in this notebook.
    "C 1s": "#8C8C8C",      # carbon: neutral grey
    "N 1s": "#2F80ED",      # nitrogen: blue
    "O 1s": "#EB5757",      # oxygen: red
    "S 2p": "#F2C94C",      # sulfur: gold/yellow
    "Cl 2p": "#27AE60",     # chlorine: green

    # Aliases commonly parsed from .VGD filenames/core-level names.
    "C1s": "#8C8C8C",
    "C1s_Scan": "#8C8C8C",
    "N1s": "#2F80ED",
    "N1s_Scan": "#2F80ED",
    "O1s": "#EB5757",
    "O1s_Scan": "#EB5757",
    "S2p": "#F2C94C",
    "S2p_Scan": "#F2C94C",
    "Cl2p": "#27AE60",
    "Cl2p_Scan": "#27AE60",
}

# %% [markdown]
# ## Survey Scan

# %%
vgd_path = Path("PDI-H-COOH/XPS Survey.VGD")
output_dir = Path("processed_xps/PDI-H-COOH")

output_name = "pdi_h_cooh_xps_survey"
figure_title = "PDI-H-COOH XPS Survey Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="survey",
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-H-COOH/XPS Survey.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_survey_extracted.csv
# Saved figure to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_survey_normalised.png
# Saved figure to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_survey_normalised.pdf
# (PosixPath('processed_xps/PDI-H-COOH/pdi_h_cooh_xps_survey_normalised.png'),
#  PosixPath('processed_xps/PDI-H-COOH/pdi_h_cooh_xps_survey_normalised.pdf'))

# %%
vgd_path = Path("PDI-Me-COOH/XPS Survey.VGD")
output_dir = Path("processed_xps/PDI-Me-COOH")

output_name = "pdi_me_cooh_xps_survey"
figure_title = "PDI-Me-COOH XPS Survey Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="survey",
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-Me-COOH/XPS Survey.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_survey_extracted.csv
# Saved figure to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_survey_normalised.png
# Saved figure to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_survey_normalised.pdf
# (PosixPath('processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_survey_normalised.png'),
#  PosixPath('processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_survey_normalised.pdf'))

# %%
vgd_path = Path("PDI-OMe-COOH/XPS Survey.VGD")
output_dir = Path("processed_xps/PDI-OMe-COOH")

output_name = "pdi_ome_cooh_xps_survey"
figure_title = "PDI-OMe-COOH XPS Survey Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="survey",
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-OMe-COOH/XPS Survey.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_survey_extracted.csv
# Saved figure to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_survey_normalised.png
# Saved figure to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_survey_normalised.pdf
# (PosixPath('processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_survey_normalised.png'),
#  PosixPath('processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_survey_normalised.pdf'))

# %% [markdown]
# ## PDI-H-COOH

# %%
vgd_path = Path("PDI-H-COOH/C1s Scan.VGD")
output_dir = Path("processed_xps/PDI-H-COOH")

output_name = "pdi_h_cooh_xps_c1s_scan"
figure_title = "PDI-H-COOH C 1s Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["C 1s"][0],
    be_max=PEAK_WINDOWS["C 1s"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-H-COOH/C1s Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_c1s_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_c1s_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_c1s_scan_normalised.png
# Saved figure to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_c1s_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-H-COOH/pdi_h_cooh_xps_c1s_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-H-COOH/pdi_h_cooh_xps_c1s_scan_normalised.pdf'))

# %%
vgd_path = Path("PDI-H-COOH/N1s Scan.VGD")
output_dir = Path("processed_xps/PDI-H-COOH")

output_name = "pdi_h_cooh_xps_n1s_scan"
figure_title = "PDI-H-COOH N 1s Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["N 1s"][0],
    be_max=PEAK_WINDOWS["N 1s"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-H-COOH/N1s Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_n1s_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_n1s_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_n1s_scan_normalised.png
# Saved figure to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_n1s_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-H-COOH/pdi_h_cooh_xps_n1s_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-H-COOH/pdi_h_cooh_xps_n1s_scan_normalised.pdf'))

# %%
vgd_path = Path("PDI-H-COOH/O1s Scan.VGD")
output_dir = Path("processed_xps/PDI-H-COOH")

output_name = "pdi_h_cooh_xps_o1s_scan"
figure_title = "PDI-H-COOH O 1s Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["O 1s"][0],
    be_max=PEAK_WINDOWS["O 1s"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-H-COOH/O1s Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_o1s_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_o1s_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_o1s_scan_normalised.png
# Saved figure to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_o1s_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-H-COOH/pdi_h_cooh_xps_o1s_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-H-COOH/pdi_h_cooh_xps_o1s_scan_normalised.pdf'))

# %%
vgd_path = Path("PDI-H-COOH/Cl2p Scan.VGD")
output_dir = Path("processed_xps/PDI-H-COOH")

output_name = "pdi_h_cooh_xps_cl2p_scan"
figure_title = "PDI-H-COOH Cl 2p Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["Cl 2p"][0],
    be_max=PEAK_WINDOWS["Cl 2p"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-H-COOH/Cl2p Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_cl2p_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_cl2p_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_cl2p_scan_normalised.png
# Saved figure to: processed_xps/PDI-H-COOH/pdi_h_cooh_xps_cl2p_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-H-COOH/pdi_h_cooh_xps_cl2p_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-H-COOH/pdi_h_cooh_xps_cl2p_scan_normalised.pdf'))

# %% [markdown]
# ## PDI-Me-COOH

# %%
vgd_path = Path("PDI-Me-COOH/C1s Scan.VGD")
output_dir = Path("processed_xps/PDI-Me-COOH")

output_name = "pdi_me_cooh_xps_c1s_scan"
figure_title = "PDI-Me-COOH C 1s Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["C 1s"][0],
    be_max=PEAK_WINDOWS["C 1s"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-Me-COOH/C1s Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_c1s_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_c1s_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_c1s_scan_normalised.png
# Saved figure to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_c1s_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_c1s_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_c1s_scan_normalised.pdf'))

# %%
vgd_path = Path("PDI-Me-COOH/N1s Scan.VGD")
output_dir = Path("processed_xps/PDI-Me-COOH")

output_name = "pdi_me_cooh_xps_n1s_scan"
figure_title = "PDI-Me-COOH N 1s Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["N 1s"][0],
    be_max=PEAK_WINDOWS["N 1s"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-Me-COOH/N1s Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_n1s_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_n1s_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_n1s_scan_normalised.png
# Saved figure to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_n1s_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_n1s_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_n1s_scan_normalised.pdf'))

# %%
vgd_path = Path("PDI-Me-COOH/O1s Scan.VGD")
output_dir = Path("processed_xps/PDI-Me-COOH")

output_name = "pdi_me_cooh_xps_o1s_scan"
figure_title = "PDI-Me-COOH O 1s Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["O 1s"][0],
    be_max=PEAK_WINDOWS["O 1s"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-Me-COOH/O1s Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_o1s_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_o1s_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_o1s_scan_normalised.png
# Saved figure to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_o1s_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_o1s_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_o1s_scan_normalised.pdf'))

# %%
vgd_path = Path("PDI-Me-COOH/Cl2p Scan.VGD")
output_dir = Path("processed_xps/PDI-Me-COOH")

output_name = "pdi_me_cooh_xps_cl2p_scan"
figure_title = "PDI-Me-COOH Cl 2p Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["Cl 2p"][0],
    be_max=PEAK_WINDOWS["Cl 2p"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-Me-COOH/Cl2p Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_cl2p_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_cl2p_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_cl2p_scan_normalised.png
# Saved figure to: processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_cl2p_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_cl2p_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-Me-COOH/pdi_me_cooh_xps_cl2p_scan_normalised.pdf'))

# %% [markdown]
# ## PDI-OMe-COOH

# %%
vgd_path = Path("PDI-OMe-COOH/C1s Scan.VGD")
output_dir = Path("processed_xps/PDI-OMe-COOH")

output_name = "pdi_ome_cooh_xps_c1s_scan"
figure_title = "PDI-OMe-COOH C 1s Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["C 1s"][0],
    be_max=PEAK_WINDOWS["C 1s"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-OMe-COOH/C1s Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_c1s_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_c1s_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_c1s_scan_normalised.png
# Saved figure to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_c1s_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_c1s_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_c1s_scan_normalised.pdf'))

# %%
vgd_path = Path("PDI-OMe-COOH/N1s Scan.VGD")
output_dir = Path("processed_xps/PDI-OMe-COOH")

output_name = "pdi_me_cooh_xps_n1s_scan"
figure_title = "PDI-Me-COOH N 1s Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["N 1s"][0],
    be_max=PEAK_WINDOWS["N 1s"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-OMe-COOH/N1s Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-OMe-COOH/pdi_me_cooh_xps_n1s_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-OMe-COOH/pdi_me_cooh_xps_n1s_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-OMe-COOH/pdi_me_cooh_xps_n1s_scan_normalised.png
# Saved figure to: processed_xps/PDI-OMe-COOH/pdi_me_cooh_xps_n1s_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-OMe-COOH/pdi_me_cooh_xps_n1s_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-OMe-COOH/pdi_me_cooh_xps_n1s_scan_normalised.pdf'))

# %%
vgd_path = Path("PDI-OMe-COOH/O1s Scan.VGD")
output_dir = Path("processed_xps/PDI-OMe-COOH")

output_name = "pdi_ome_cooh_xps_o1s_scan"
figure_title = "PDI-OMe-COOH O 1s Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["O 1s"][0],
    be_max=PEAK_WINDOWS["O 1s"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-OMe-COOH/O1s Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_o1s_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_o1s_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_o1s_scan_normalised.png
# Saved figure to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_o1s_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_o1s_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_o1s_scan_normalised.pdf'))

# %%
vgd_path = Path("PDI-OMe-COOH/Cl2p Scan.VGD")
output_dir = Path("processed_xps/PDI-OMe-COOH")

output_name = "pdi_ome_cooh_xps_cl2p_scan"
figure_title = "PDI-OMe-COOH Cl 2p Scan"

xps_df = read_vgd_to_dataframe(vgd_path)
xps_df = add_normalised_intensity(xps_df, intensity_column="corrected_intensity")

peak_df = extract_peak_maximum(
    xps_df=xps_df,
    be_min=PEAK_WINDOWS["Cl 2p"][0],
    be_max=PEAK_WINDOWS["Cl 2p"][1],
    intensity_column="corrected_intensity",
    smoothing_window=5,
)

save_xps_outputs(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
)

save_khervefitting_xlsx(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    intensity_column="corrected_intensity",
)

peak_df.to_csv(output_dir / f"{output_name}_peak_maximum.csv", index=False)

plot_normalised_xps(
    xps_df=xps_df,
    output_dir=output_dir,
    output_name=output_name,
    figure_title=figure_title,
    mode="core_level",
    peak_df=peak_df,
    colour_map=CORE_LEVEL_COLOURS,
)
# Out:
# File: PDI-OMe-COOH/Cl2p Scan.VGD
# Number of spectra found: 1
# Saved CSV to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_cl2p_scan_extracted.csv
# Saved KherveFitting XLSX to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_cl2p_scan_for_khervefitting.xlsx
# Saved figure to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_cl2p_scan_normalised.png
# Saved figure to: processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_cl2p_scan_normalised.pdf
# (PosixPath('processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_cl2p_scan_normalised.png'),
#  PosixPath('processed_xps/PDI-OMe-COOH/pdi_ome_cooh_xps_cl2p_scan_normalised.pdf'))
